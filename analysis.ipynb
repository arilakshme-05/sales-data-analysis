# %% [markdown]
# <a href="https://colab.research.google.com/github/arilakshme-05/sales-data-analysis/blob/main/analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = {
    "Date": ["2025-11-01","2025-11-01","2025-11-02","2025-11-02",
             "2025-11-03","2025-11-03","2025-11-04","2025-11-04"],
    "Product": ["Pen","Notebook","Pen","Notebook","Eraser","Pen","Notebook","Eraser"],
    "Quantity": [10,5,7,3,15,5,2,10],
    "Price": [5,20,5,20,2,5,20,2]
}

df = pd.DataFrame(data)
df.to_csv("sample_sales.csv", index=False)
print("Sample CSV 'sample_sales.csv' created!")
df = pd.read_csv("sample_sales.csv")
print("\n----- HEAD OF DATA -----")
print(df.head())
print("\n----- INFO -----")
print(df.info())
print("\nShape of DataFrame:", df.shape)
print("\nMissing Values:\n", df.isna().sum())
df = df.dropna()
df['Total'] = df['Quantity'] * df['Price']
sales_by_product = df.groupby("Product")["Total"].sum()
print("\n----- TOTAL SALES BY PRODUCT -----")
print(sales_by_product)
daily_sales = df.groupby("Date")["Total"].sum()
print("\n----- DAILY SALES -----")
print(daily_sales)
plt.figure(figsize=(7,5))
sales_by_product.plot(kind='bar', color='skyblue')
plt.title("Total Sales by Product")
plt.xlabel("Product")
plt.ylabel("Sales Amount")
plt.tight_layout()
plt.show()
plt.figure(figsize=(8,5))
daily_sales.plot(kind='line', marker='o', color='green')
plt.title("Daily Sales Trend")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Sample CSV 'sample_sales.csv' created!
#
# ----- HEAD OF DATA -----
#          Date   Product  Quantity  Price
# 0  2025-11-01       Pen        10      5
# 1  2025-11-01  Notebook         5     20
# 2  2025-11-02       Pen         7      5
# 3  2025-11-02  Notebook         3     20
# 4  2025-11-03    Eraser        15      2
#
# ----- INFO -----
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      8 non-null      object
#  1   Product   8 non-null      object
#  2   Quantity  8 non-null      int64
#  3   Price     8 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 388.0+ bytes
# None
#
# Shape of DataFrame: (8, 4)
#
# Missing Values:
#  Date        0
# Product     0
# Quantity    0
# Price       0
# dtype: int64
#
# ----- TOTAL SALES BY PRODUCT -----
# Product
# Eraser       50
# Notebook    200
# Pen         110
# ...
